# %% [markdown]
# <a href="https://colab.research.google.com/github/SteAmarante/python-data-science/blob/main/aula_05/exercicios_1_ao_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exercícios Individuais – Importação e exploração inicial

# %%
import pandas as pd

# %% [markdown]
# ##1 – Carregue um dos arquivos de vinhos disponibilizados (menos csv) e exiba:
#
# As 5 primeiras linhas (df.head()),
#
# - O formato (df.shape),
# - A lista de colunas e seus tipos (df.dtypes),
# - Um resumo estatístico (df.describe()).

# %%
df = pd.read_json("/content/vinhos.json", lines=True)
df
# Out:
#        year  month location location_type    category grape_type  volume_hl  \
# 0      2015      1       AC  Brazil_State  Production      Table        910
# 1      2015      1       AC  Brazil_State  Production       Wine       3822
# 2      2015      1       AC  Brazil_State  Production  Sparkling        516
# 3      2015      1       AC  Brazil_State       Sales      Table       3494
# 4      2015      1       AC  Brazil_State       Sales       Wine        180
# ...     ...    ...      ...           ...         ...        ...        ...
# 26635  2024     12    China       Country      Import       Wine       3574
# 26636  2024     12    China       Country      Import  Sparkling        825
# 26637  2024     12    China       Country      Export      Table       2115
# 26638  2024     12    China       Country      Export       Wine       2107
# 26639  2024     12    China       Country      Export  Sparkling       6813
#
#        value_usd
# 0        1782.31
# 1       11435.90
# ...

# %%
df.head()
# Out:
#    year  month location location_type    category grape_type  volume_hl  \
# 0  2015      1       AC  Brazil_State  Production      Table        910
# 1  2015      1       AC  Brazil_State  Production       Wine       3822
# 2  2015      1       AC  Brazil_State  Production  Sparkling        516
# 3  2015      1       AC  Brazil_State       Sales      Table       3494
# 4  2015      1       AC  Brazil_State       Sales       Wine        180
#
#    value_usd
# 0    1782.31
# 1   11435.90
# 2     902.97
# 3   10491.74
# 4     279.26

# %%
df.shape
# Out:
# (26640, 8)

# %%
df.dtypes
# Out:
# year               int64
# month              int64
# location          object
# location_type     object
# category          object
# grape_type        object
# volume_hl          int64
# value_usd        float64
# dtype: object

# %%
df.describe()
# Out:
#                year         month     volume_hl    value_usd
# count  26640.000000  26640.000000  26640.000000  26640.00000
# mean    2019.500000      6.500000   2798.185135   8398.65186
# std        2.872335      3.452117   1666.405404   6071.43803
# min     2015.000000      1.000000     50.000000     87.07000
# 25%     2017.000000      3.750000   1393.000000   3721.98000
# 50%     2019.500000      6.500000   2736.000000   7368.98500
# 75%     2022.000000      9.250000   4068.000000  11741.85750
# max     2024.000000     12.000000   6996.000000  34273.99000

# %% [markdown]
# ##2 – Neste mesmo data frame aplique df.describe().T

# %%
df.describe().T
# Out:
#              count         mean          std      min      25%       50%  \
# year       26640.0  2019.500000     2.872335  2015.00  2017.00  2019.500
# month      26640.0     6.500000     3.452117     1.00     3.75     6.500
# volume_hl  26640.0  2798.185135  1666.405404    50.00  1393.00  2736.000
# value_usd  26640.0  8398.651860  6071.438030    87.07  3721.98  7368.985
#
#                   75%       max
# year        2022.0000   2024.00
# month          9.2500     12.00
# volume_hl   4068.0000   6996.00
# value_usd  11741.8575  34273.99

# %% [markdown]
# ##3 – Adicione pelo menos 20 valores vazios espalhados pelas colunas em um dataFrame cópia, após isso use o .isnull() com .sum() para ver como ficou a dispersão de vazios

# %%
df2 = df.copy()
df2.loc[2:5,'value_usd'] = None # 4 valores vazios
df2.loc[5:10,'location_type'] = None # 6 valores vazios
df2.loc[1:5,'month']= None # 5 valores vazios
df2.loc[7:11,'volume_hl']= None # 5 valores vazios
df2.head(20)
# Out:
#     year  month location location_type    category grape_type  volume_hl  \
# 0   2015    1.0       AC  Brazil_State  Production      Table      910.0
# 1   2015    NaN       AC  Brazil_State  Production       Wine     3822.0
# 2   2015    NaN       AC  Brazil_State  Production  Sparkling      516.0
# 3   2015    NaN       AC  Brazil_State       Sales      Table     3494.0
# 4   2015    NaN       AC  Brazil_State       Sales       Wine      180.0
# 5   2015    NaN       AC          None       Sales  Sparkling      819.0
# 6   2015    2.0       AC          None  Production      Table     2483.0
# 7   2015    2.0       AC          None  Production       Wine        NaN
# 8   2015    2.0       AC          None  Production  Sparkling        NaN
# 9   2015    2.0       AC          None       Sales      Table        NaN
# 10  2015    2.0       AC          None       Sales       Wine        NaN
# 11  2015    2.0       AC  Brazil_State       Sales  Sparkling        NaN
# ...

# %%
df2.isnull().sum()
# Out:
# year             0
# month            5
# location         0
# location_type    6
# category         0
# grape_type       0
# volume_hl        5
# value_usd        4
# dtype: int64

# %% [markdown]
# ##4 – Nesse dataFrame cópia utilize o df.describe().T e o compare com o do dataFrame orginal

# %%
print("Cópia df original\n")
df2.describe().T
# Out:
# Cópia df original
#              count         mean          std      min        25%      50%  \
# year       26640.0  2019.500000     2.872335  2015.00  2017.0000  2019.50
# month      26635.0     6.501032     3.451619     1.00     4.0000     7.00
# volume_hl  26635.0  2798.275502  1666.476058    50.00  1393.5000  2736.00
# value_usd  26636.0  8399.373208  6071.402620    87.07  3722.5525  7370.08
#
#                 75%       max
# year        2022.00   2024.00
# month         10.00     12.00
# volume_hl   4068.00   6996.00
# value_usd  11742.23  34273.99

# %%
print("Df original\n")
df.describe().T
# Out:
# Df original
#              count         mean          std      min      25%       50%  \
# year       26640.0  2019.500000     2.872335  2015.00  2017.00  2019.500
# month      26640.0     6.500000     3.452117     1.00     3.75     6.500
# volume_hl  26640.0  2798.185135  1666.405404    50.00  1393.00  2736.000
# value_usd  26640.0  8398.651860  6071.438030    87.07  3721.98  7368.985
#
#                   75%       max
# year        2022.0000   2024.00
# month          9.2500     12.00
# volume_hl   4068.0000   6996.00
# value_usd  11741.8575  34273.99
